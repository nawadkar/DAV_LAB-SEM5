# %% [markdown]
# # **Experiment 7**
# *   Name: Atharva Nawadkar
# *   Class: D11AD
# *   Roll No: 43
#
# **Aim:** Perform the steps involved in Text Analytics in Python & R
#
# **Task To be performed:**
#
# 1.   Explore Top-5 Text Analytics Libraries in Python (w.r.t Features & Applications)
# 2.   Explore Top-5 Text Analytics Libraries in R (w.r.t Features & Applications)
# 3.   Perform the following experiments using Python & R
#
# *   Tokenization (Sentence & Word)
# *   Frequency Distribution
# *   Remove stopwords & punctuations
# *   Lexicon Normalization (Stemming, Lemmatization)
# *   Part of Speech tagging
# *   Named Entity Recognization
# *   Scrape data from a website
#
# 4.   Prepare a document with the Aim, Tasks performed, Program, Output, and Conclusion.

# %% [markdown]
# ## **Theory:**
#
# ## **Text Analytics Libraries in Python**
#
# ### **NLTK (Natural Language Toolkit):**
#
# >**Features:**
# *   Comprehensive set of tools for natural language processing (NLP).
# *   Includes modules for tokenization, stemming, tagging, parsing, and more.
#
#
# >**Applications:**
# *   Text classification, sentiment analysis, language translation, and information retrieval.
# *   Widely used for educational purposes in teaching NLP concepts.
#
#
#
# ### **TextBlob:**
# >**Features:**
# *   Simplified API for common NLP tasks.
# *   Built on the NLTK and Pattern libraries, providing easy-to-use functions.
#
# >**Applications:**
# *   Sentiment analysis, part-of-speech tagging, noun phrase extraction.
# *   Quick and simple text processing for beginners and small-scale projects.
#
#
#
# ### **spaCy:**
#
# >**Features:**
# *   Efficient and fast processing of large amounts of text.
# *   Pre-trained models for various languages and support for custom models.
#
# >**Applications:**
# *   Named entity recognition, dependency parsing, information extraction.
# *   Ideal for production-level applications due to its speed and scalability.
#
#
# ### **Gensim:**
#
# >**Features:**
# *   Topic modeling and document similarity analysis.
# *   Implementation of Word2Vec and Doc2Vec models for word and document embeddings.
#
# >**Applications:**
# *   Document clustering, document summarization, and semantic similarity analysis.
# *   Popular in academic and industry research for large-scale text analysis.
#
#
#
#
# ### **Scikit-learn:**
#
# >**Features:**
# *   General-purpose machine learning library with text processing capabilities.
# *   Integrates seamlessly with other Python libraries, such as NumPy and Pandas.
#
# >**Applications:**
# *   Text classification, document clustering, and feature extraction.
# *   Useful for combining text analytics with traditional machine learning tasks.

# %% [markdown]
# ## **Text Analytics Libraries in R**
#
# ### **tm (Text Mining) Package:**
#
# > **Features:**
# *   Efficient text preprocessing functions, including stemming and stopword removal.
# *   Integration with various text corpora and easy creation of term-document matrices.
#
# > **Applications:**
# *   Document classification, sentiment analysis, and topic modeling.
# *   Used for analyzing and mining text data from diverse sources.
#
#
#
#
#
#
#
#
# ### **quanteda:**
#
# >**Features:**
# *   Flexible and intuitive functions for text processing and corpus creation.
# *   Support for advanced text analysis techniques like n-grams and text scaling.
#
# >**Applications:**
# *   Textual data exploration, sentiment analysis, and network text analysis.
# *   Popular in social sciences and quantitative research for analyzing large text corpora.
#
#
# ### **tmtoolkit:**
#
# >**Features:**
# *   Integration with tm and quanteda, providing additional functionality.
# *   Comprehensive text analysis tools, including sentiment analysis and keyword extraction.
#
# >**Applications:**
# *   Social media analytics, sentiment analysis, and comparative text analysis.
# *   Suitable for analyzing text data in a wide range of domains.
#
#
#
#
# ### **textTinyR:**
#
# >**Features:**
# *   Lightweight package with functions for text preprocessing and exploration.
# *   Useful for quick and efficient analysis of small to medium-sized text datasets.
#
# >**Applications:**
# *   Basic text mining tasks, such as term frequency analysis and word cloud creation.
# *   Ideal for users seeking a simplified package for initial text analysis.
#
#
#
# ### **caret:**
#
# >**Features:**
# *   General-purpose machine learning package with text-specific functionalities.
# *   Integration with various algorithms and easy model training for text classification.
#
# >**Applications:**
# *   Text classification, sentiment analysis, and document clustering.
# *   Suitable for users familiar with the caret ecosystem who want to extend their analyses to text data.

# %% [markdown]
# ## **Python Implementation**

# %%
import nltk
nltk.download("punkt")
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ### **Tokenization**

# %%
from nltk.tokenize import sent_tokenize
text="""And once the storm is over you won’t remember how you made it through, how you managed to survive. You won’t even be sure, in fact, whether the storm is really over. But one thing is certain. When you come out of the storm you won’t be the same person who walked in. That’s what this storm’s all about"""

tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['And once the storm is over you won’t remember how you made it through, how you managed to survive.', 'You won’t even be sure, in fact, whether the storm is really over.', 'But one thing is certain.', 'When you come out of the storm you won’t be the same person who walked in.', 'That’s what this storm’s all about']

# %%
from nltk.tokenize import word_tokenize

tokenized_word=word_tokenize(text)

print(tokenized_word)
# Out:
# ['And', 'once', 'the', 'storm', 'is', 'over', 'you', 'won', '’', 't', 'remember', 'how', 'you', 'made', 'it', 'through', ',', 'how', 'you', 'managed', 'to', 'survive', '.', 'You', 'won', '’', 't', 'even', 'be', 'sure', ',', 'in', 'fact', ',', 'whether', 'the', 'storm', 'is', 'really', 'over', '.', 'But', 'one', 'thing', 'is', 'certain', '.', 'When', 'you', 'come', 'out', 'of', 'the', 'storm', 'you', 'won', '’', 't', 'be', 'the', 'same', 'person', 'who', 'walked', 'in', '.', 'That', '’', 's', 'what', 'this', 'storm', '’', 's', 'all', 'about']

# %% [markdown]
# ### **Frequency Distribution**

# %%
from nltk.probability import FreqDist

fdist = FreqDist(tokenized_word)
print(fdist.most_common(2))
# Out:
# [('you', 5), ('’', 5)]

# %%
import matplotlib.pyplot as plt

fdist.plot(30,cumulative=False)
plt.show()

# %% [markdown]
# ### **Stopwords**

# %%
from nltk.corpus import stopwords

stop_words=set(stopwords.words("english"))

print(stop_words)
# Out:
# {'ma', 'over', 'too', "you'll", 'all', 'have', 'their', 'didn', 'than', 'of', 'those', 't', "isn't", 'down', "haven't", 'shan', 'at', 'itself', 'its', "it's", 'should', 'ain', 'below', 'on', "hasn't", 'just', 'me', 'mustn', 'the', 'or', 'through', 'only', 'above', 'how', 'can', 'does', 'ours', 'himself', 'this', 'because', 'out', 'other', 'not', 'doing', 'y', 'her', "shan't", 'off', 'further', 'while', 'both', 'his', 'you', 'them', 'couldn', 'shouldn', 'weren', 'with', 'very', 'herself', 'against', 'yourselves', 'doesn', 'we', 'here', 'd', "don't", 'hers', 'him', 'my', 'he', 'hadn', 'any', 'now', 'has', 'did', 'but', 'be', 'no', 'same', 'having', 'again', 'isn', 'when', "she's", 'an', 'nor', 've', 'where', 'needn', 'into', 're', 'mightn', "didn't", 'yourself', "aren't", 'will', 'from', 'ourselves', 'each', 'about', 'more', 'i', 'had', 'our', 'these', 'being', 'as', "weren't", "mustn't", "you've", 'it', 'and', 's', 'so', 'there', 'aren', 'themselves', 'wasn', 'what', 'if', 'they', "sh
# ...

# %% [markdown]
# **Removing Stopwords**

# %%
filtered_tokens=[]
for w in tokenized_word:
    if w not in stop_words:
         filtered_tokens.append(w)

print("Tokenized Words:",tokenized_word)
print("Filterd Tokens:",filtered_tokens)
# Out:
# Tokenized Words: ['And', 'once', 'the', 'storm', 'is', 'over', 'you', 'won', '’', 't', 'remember', 'how', 'you', 'made', 'it', 'through', ',', 'how', 'you', 'managed', 'to', 'survive', '.', 'You', 'won', '’', 't', 'even', 'be', 'sure', ',', 'in', 'fact', ',', 'whether', 'the', 'storm', 'is', 'really', 'over', '.', 'But', 'one', 'thing', 'is', 'certain', '.', 'When', 'you', 'come', 'out', 'of', 'the', 'storm', 'you', 'won', '’', 't', 'be', 'the', 'same', 'person', 'who', 'walked', 'in', '.', 'That', '’', 's', 'what', 'this', 'storm', '’', 's', 'all', 'about']
# Filterd Tokens: ['And', 'storm', '’', 'remember', 'made', ',', 'managed', 'survive', '.', 'You', '’', 'even', 'sure', ',', 'fact', ',', 'whether', 'storm', 'really', '.', 'But', 'one', 'thing', 'certain', '.', 'When', 'come', 'storm', '’', 'person', 'walked', '.', 'That', '’', 'storm', '’']

# %% [markdown]
# **Removing Punctuations**

# %%
import string

# punctuations
punctuations=list(string.punctuation)
punctuations.append('’')

filtered_tokens2=[]

for i in filtered_tokens:
    if i not in punctuations:
        filtered_tokens2.append(i)

print("Filterd Tokens After Removing Punctuations:",filtered_tokens2)
# Out:
# Filterd Tokens After Removing Punctuations: ['And', 'storm', 'remember', 'made', 'managed', 'survive', 'You', 'even', 'sure', 'fact', 'whether', 'storm', 'really', 'But', 'one', 'thing', 'certain', 'When', 'come', 'storm', 'person', 'walked', 'That', 'storm']

# %% [markdown]
# ### **Lexicon Normalization**
#
# **Stemming**

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()

stemmed_words=[]

for w in filtered_tokens2:
     stemmed_words.append(ps.stem(w))

print("Filtered Tokens After Removing Punctuations:",filtered_tokens2)
print("Stemmed Tokens:",stemmed_words)
# Out:
# Filtered Tokens After Removing Punctuations: ['And', 'storm', 'remember', 'made', 'managed', 'survive', 'You', 'even', 'sure', 'fact', 'whether', 'storm', 'really', 'But', 'one', 'thing', 'certain', 'When', 'come', 'storm', 'person', 'walked', 'That', 'storm']
# Stemmed Tokens: ['and', 'storm', 'rememb', 'made', 'manag', 'surviv', 'you', 'even', 'sure', 'fact', 'whether', 'storm', 'realli', 'but', 'one', 'thing', 'certain', 'when', 'come', 'storm', 'person', 'walk', 'that', 'storm']

# %% [markdown]
# **Lemmatization**

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

lem = WordNetLemmatizer()
stem = PorterStemmer()
word = "flying"

print("Lemmatized Word:",lem.lemmatize(word,"v"))
print("Stemmed Word:",stem.stem(word))

lem_words=[]
for w in filtered_tokens2:
     stemmed_words.append(ps.lemmatize(w))

print(text)
print("Lemmatized Word:",lem_words)
print("Stemmed Word:",stem.stem(text))
# Out:
# Lemmatized Word: fly
# Stemmed Word: fli
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-6df0655c8c05> in <cell line: 12>()
#      11 lem_words=[]
#      12 for w in filtered_tokens2:
# ---> 13      stemmed_words.append(ps.lemmatize(w))
#      14
#      15 print(text)
#
# AttributeError: 'PorterStemmer' object has no attribute 'lemmatize'

# %% [markdown]
# ### **POS tagging**

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag

sent = "Albert Einstein was born in Ulm, Germany in 1879."

tokens=word_tokenize(sent)
pos_=pos_tag(tokens)


print("Tokens:",tokens)
print("PoS tags:",pos_)
# Out:
# Tokens: ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germany', 'in', '1879', '.']
# PoS tags: [('Albert', 'NNP'), ('Einstein', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('in', 'IN'), ('Ulm', 'NNP'), (',', ','), ('Germany', 'NNP'), ('in', 'IN'), ('1879', 'CD'), ('.', '.')]

# %% [markdown]
# ### **Named Entity Recognization**

# %%
from nltk import ne_chunk

sent="New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases."

for chunk in ne_chunk(nltk.pos_tag(word_tokenize(sent))):
        if hasattr(chunk, 'label'):
           print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# GPE New York City

# %% [markdown]
# ### **Web Scraping**

# %%
import pandas as pd
import os
import requests
from bs4 import BeautifulSoup

# %%
def scrape(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        title = soup.find('h1').get_text()
        print("Article Title: \n" + title)
        text = soup.find('div', class_= 'td-post-content')

        if text:
          pre_tag = text.find('pre')
          if pre_tag:
            pre_tag.decompose()

        new_text = text.get_text()
        print("\n\nArticle Text: " + new_text)

# %%
scrape("https://insights.blackcoffer.com/rise-of-e-health-and-its-impact-on-humans-by-the-year-2030/")
# Out:
# Article Title:
# Rise of e-health and its impact on humans by the year 2030
#
#
# Article Text:
# The rise of e-health, or the use of electronic means to facilitate health care, has been a major development in the healthcare industry in recent years. The use of technology to improve access to healthcare and make it more efficient has the potential to revolutionize the way we think about healthcare and its delivery. By 2030, it is likely that e-health will have a significant impact on the way we receive and provide healthcare, and this essay will explore the potential impacts of e-health on humans by that year.
# ...

# %% [markdown]
# ## **R Implementation**

# %%
install.packages("tm")
install.packages("rvest")
install.packages("tokenizers")
install.packages("openNLP")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘NLP’, ‘Rcpp’, ‘slam’, ‘BH’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘SnowballC’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘openNLPdata’, ‘rJava’
#
#
# Warning message in install.packages("openNLP"):
# “installation of package ‘rJava’ had non-zero exit status”
# Warning message in install.packages("openNLP"):
# “installation of package ‘openNLPdata’ had non-zero exit status”
# Warning message in install.packages("openNLP"):
# “installation of package ‘openNLP’ had non-zero exit status”

# %%
library(tm)
library(rvest)
library(NLP)
library(tokenizers)
library(SnowballC)
# Out:
# Loading required package: NLP

# %%
text <- "And once the storm is over you won’t remember how you made it through, how you managed to survive. You won’t even be sure, in fact, whether the storm is really over. But one thing is certain. When you come out of the storm you won’t be the same person who walked in. That’s what this storm’s all about"

sent_tokens <- unlist(tokenize_sentences(text))
word_tokens <- unlist(tokenize_words(text))
cat("Sentence Tokens:", sent_tokens, "\n")
cat("Word Tokens:", word_tokens, "\n")
# Frequency Distribution
fdist <- table(unlist(word_tokens))
print(head(sort(fdist, decreasing = TRUE), 2))
# Out:
# Sentence Tokens: And once the storm is over you won’t remember how you made it through, how you managed to survive. You won’t even be sure, in fact, whether the storm is really over. But one thing is certain. When you come out of the storm you won’t be the same person who walked in. That’s what this storm’s all about
# Word Tokens: and once the storm is over you won’t remember how you made it through how you managed to survive you won’t even be sure in fact whether the storm is really over but one thing is certain when you come out of the storm you won’t be the same person who walked in that’s what this storm’s all about
#
# you the
#   6   4

# %%
# Remove stopwords and punctuations
stop_words <- stopwords("en")
filtered_tokens <- word_tokens[!(word_tokens %in% stop_words) & grepl("[a-zA-Z]", word_tokens)]
cat("Filtered Tokens (without stopwords and punctuations):", filtered_tokens, "\n")
# Out:
# Filtered Tokens (without stopwords and punctuations): storm won’t remember made managed survive won’t even sure fact whether storm really one thing certain come storm won’t person walked that’s storm’s

# %%
# Stemming
stemmed_tokens <- wordStem(filtered_tokens, language = "en")

# Lemmatization
lemmatized_text <- tolower(text)
lemmatized_text <- wordStem(lemmatized_text, language = "en")
cat("Stemmed Tokens:", stemmed_tokens, "\n")
cat("Lemmatized Text:", lemmatized_text, "\n")
# Out:
# Stemmed Tokens: storm won’t rememb made manag surviv won’t even sure fact whether storm realli one thing certain come storm won’t person walk that’ storm’
# Lemmatized Text: and once the storm is over you won’t remember how you made it through, how you managed to survive. you won’t even be sure, in fact, whether the storm is really over. but one thing is certain. when you come out of the storm you won’t be the same person who walked in. that’s what this storm’s all about

# %%
# Web Scraping
url <- 'https://en.wikipedia.org/wiki/Data_analysis'
web_page <- read_html(url)
web_text <- html_text(web_page)
cat("Scraped Data from the Website:\n", web_text)
# Out:
# Scraped Data from the Website:
# ...
